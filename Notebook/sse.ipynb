# %%
import os
import numpy as np
import pandas as pd
import json

# %%
path = r"..\\Dataset\\data\\data_jsonl\\data.jsonl"
df = pd.read_json(path_or_buf=path,lines=True)

# %%
df.head()
# Out:
#          id                                        url  \
# 0   1268383   https://api.capapi.org/v1/cases/1268383/
# 1  11956941  https://api.capapi.org/v1/cases/11956941/
# 2  11645357  https://api.capapi.org/v1/cases/11645357/
# 3  11272108  https://api.capapi.org/v1/cases/11272108/
# 4  11273534  https://api.capapi.org/v1/cases/11273534/
#
#                                                 name  \
# 0                            The State vs. John Owen
# 1                              DUNLOP et al. v. WEST
# 2                                        The FORTUNA
# 3  D. K. FUTCH v. ATLANTIC COAST LINE RAILROAD CO...
# 4  MRS. SUSANNA WILLIAMS v. C. G. BAILEY, B. R. B...
#
#                        name_abbreviation decision_date   docket_number  \
# 0                          State v. Owen       1810-07
# 1                         Dunlop v. West          1805  Case No. 4,170
# 2                            The Fortuna          1815  Case No. 4,954
# 3  Futch v. Atlantic Coast Line Railroad    1919-10-15
# 4                     Williams v. Bailey    1919-12-03
#
#   first_page last_page                                          citations  \
# 0        260       262  [{'type': 'official', 'cite': '2 Wheel. Cr. Ca...
# 1         93        93  [{'type': 'official', 'cite': '8 F. Cas. 93'},...
# 2        494       500  [{'type': 'official', 'cite': '9 F. Cas. 494'}...
# 3        282       284     [{'type': 'official', 'cite': '178 N.C. 282'}]
# 4        630       633     [{'type': 'official', 'cite': '178 N.C. 630'}]
#
#                                               volume  \
# 0  {'volume_number': '2', 'barcode': '32044078486...
# 1  {'volume_number': '8', 'barcode': '32044046873...
# 2  {'volume_number': '9', 'barcode': '32044054565...
# 3  {'volume_number': '178', 'barcode': '320440578...
# 4  {'volume_number': '178', 'barcode': '320440578...
#
#                                             reporter  \
# 0  {'url': 'https://api.capapi.org/v1/reporters/1...
# 1  {'url': 'https://api.capapi.org/v1/reporters/9...
# 2  {'url': 'https://api.capapi.org/v1/reporters/9...
# 3  {'url': 'https://api.capapi.org/v1/reporters/5...
# 4  {'url': 'https://api.capapi.org/v1/reporters/5...
#
#                                                court  \
# 0  {'name': 'Supreme Court of North Carolina', 'i...
# 1  {'name': 'United States Circuit Court for the ...
# 2  {'name': 'United States Circuit Court for the ...
# 3  {'name': 'Supreme Court of North Carolina', 'i...
# 4  {'name': 'Supreme Court of North Carolina', 'i...
#
#                                         jurisdiction  \
# 0  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 1  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 2  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 3  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 4  {'name_long': 'North Carolina', 'name': 'N.C.'...
#
#                                             cites_to  \
# 0                                                 []
# 1                    [{'cite': '2 Hayw. N. C. 346'}]
# 2  [{'cite': '1 Brock. 299'}, {'cite': '3 Wheat. ...
# 3                                                 []
# 4                                                 []
#
#                                    frontend_url preview  \
# 0   https://cite.capapi.org/wheel-cr-cas/2/260/      []
# 1  https://cite.capapi.org/f-cas/8/93/11956941/      []
# 2          https://cite.capapi.org/f-cas/9/494/      []
# 3           https://cite.capapi.org/nc/178/282/      []
# 4           https://cite.capapi.org/nc/178/630/      []
#
#                                             casebody
# 0  {'status': 'ok', 'data': {'head_matter': 'SUPR...
# 1  {'status': 'ok', 'data': {'head_matter': 'Case...
# 2  {'status': 'ok', 'data': {'head_matter': 'Case...
# 3  {'status': 'ok', 'data': {'head_matter': 'D. K...
# 4  {'status': 'ok', 'data': {'head_matter': 'MRS....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97600 entries, 0 to 97599
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 97600 non-null  int64
#  1   url                97600 non-null  object
#  2   name               97600 non-null  object
#  3   name_abbreviation  97600 non-null  object
#  4   decision_date      97600 non-null  object
#  5   docket_number      97600 non-null  object
#  6   first_page         97600 non-null  object
#  7   last_page          97600 non-null  object
#  8   citations          97600 non-null  object
#  9   volume             97600 non-null  object
#  10  reporter           97600 non-null  object
#  11  court              97600 non-null  object
#  12  jurisdiction       97600 non-null  object
#  13  cites_to           97600 non-null  object
#  14  frontend_url       97600 non-null  object
#  15  preview            97600 non-null  object
#  16  casebody           97600 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 12.7+ MB

# %%
columns = ['id', 'name', 'decision_date', 'jurisdiction', 'head_matter', 'text']

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97600 entries, 0 to 97599
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 97600 non-null  int64
#  1   url                97600 non-null  object
#  2   name               97600 non-null  object
#  3   name_abbreviation  97600 non-null  object
#  4   decision_date      97600 non-null  object
#  5   docket_number      97600 non-null  object
#  6   first_page         97600 non-null  object
#  7   last_page          97600 non-null  object
#  8   citations          97600 non-null  object
#  9   volume             97600 non-null  object
#  10  reporter           97600 non-null  object
#  11  court              97600 non-null  object
#  12  jurisdiction       97600 non-null  object
#  13  cites_to           97600 non-null  object
#  14  frontend_url       97600 non-null  object
#  15  preview            97600 non-null  object
#  16  casebody           97600 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 12.7+ MB

# %%
data = df.sample(frac=0.2, random_state=42)
len(data)
# Out:
# 19520

# %%
data['head_matter'] = data['casebody'].apply(lambda x: x['data']['head_matter'])
data['text'] = data['casebody'].apply(lambda x: x['data']['opinions'][0]['text'] if len(x['data']['opinions']) > 0 else None)

# %%
data = pd.DataFrame(data=data, columns=columns)
data.dropna(inplace=True)
data.head()
# Out:
#             id                                               name  \
# 15626  8656636  E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL ...
# 43222  8615879                           STATE v. ABRAHAM L. LUFF
# 46310  8616722                             STATE v. FRANK BALLARD
# 35755  8654035  FIRST NATIONAL BANK OF SPARTANBURG, SOUTH CARO...
# 40598  8554475          STATE OF NORTH CAROLINA v. HAROLD EMANUEL
#
#       decision_date                                       jurisdiction  \
# 15626    1913-12-10  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 43222    1930-04-16  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 46310    1944-03-22  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 35755    1924-10-22  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 40598    1972-12-20  {'name_long': 'North Carolina', 'name': 'N.C.'...
#
#                                              head_matter  \
# 15626  E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL ...
# 43222  STATE v. ABRAHAM L. LUFF.\n(Filed 16 April, 19...
# 46310  STATE v. FRANK BALLARD.\n(Filed 22 March, 1944...
# 35755  FIRST NATIONAL BANK OF SPARTANBURG, SOUTH CARO...
# 40598  STATE OF NORTH CAROLINA v. HAROLD EMANUEL\nNo....
#
#                                                     text
# 15626  Clark, C. J.\nTbe plaintiff executed to defend...
# 43222  Brogden, J.\nThe defendant contended that the ...
# 46310  Pee Cueiam.\nAfter a careful consideration of ...
# 35755  Stacy, J.\nThe president and assistant cashier...
# 40598  GRAHAM, Judge.\nAfter the case was docketed an...

# %%
## Preprocessing
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Function to clean and preprocess text
def clean_text(text):
    text = text.lower()
    
    # Remove special characters, punctuation, and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # Tokenize text into words
    words = word_tokenize(text)
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Join words back into a sentence
    cleaned_text = ' '.join(words)
    
    return cleaned_text

# %%
data['cleaned_text'] = data['text'].apply(clean_text)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-distilroberta-v1')

# %%
data['Text_Embedding'] = data['cleaned_text'].apply(lambda x: model.encode(x))
data.head()
# Out:
#             id                                               name  \
# 15626  8656636  E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL ...
# 43222  8615879                           STATE v. ABRAHAM L. LUFF
# 46310  8616722                             STATE v. FRANK BALLARD
# 35755  8654035  FIRST NATIONAL BANK OF SPARTANBURG, SOUTH CARO...
# 40598  8554475          STATE OF NORTH CAROLINA v. HAROLD EMANUEL
#
#       decision_date                                       jurisdiction  \
# 15626    1913-12-10  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 43222    1930-04-16  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 46310    1944-03-22  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 35755    1924-10-22  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 40598    1972-12-20  {'name_long': 'North Carolina', 'name': 'N.C.'...
#
#                                              head_matter  \
# 15626  E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL ...
# 43222  STATE v. ABRAHAM L. LUFF.\n(Filed 16 April, 19...
# 46310  STATE v. FRANK BALLARD.\n(Filed 22 March, 1944...
# 35755  FIRST NATIONAL BANK OF SPARTANBURG, SOUTH CARO...
# 40598  STATE OF NORTH CAROLINA v. HAROLD EMANUEL\nNo....
#
#                                                     text  \
# 15626  Clark, C. J.\nTbe plaintiff executed to defend...
# 43222  Brogden, J.\nThe defendant contended that the ...
# 46310  Pee Cueiam.\nAfter a careful consideration of ...
# 35755  Stacy, J.\nThe president and assistant cashier...
# 40598  GRAHAM, Judge.\nAfter the case was docketed an...
#
#                                             cleaned_text  \
# 15626  clark c j tbe plaintiff executed defendant bur...
# 43222  brogden j defendant contended fund deposited c...
# 46310  pee cueiam careful consideration defendant exc...
# 35755  stacy j president assistant cashier plaintiff ...
# 40598  graham judge case docketed brief filed court d...
#
#                                           Text_Embedding
# 15626  [0.014324145, 0.013309592, -0.01312468, 0.0038...
# 43222  [0.02646342, -0.011471986, 0.017028704, -0.029...
# 46310  [0.0046529677, 0.0053747525, -0.023658633, -0....
# 35755  [0.009116395, -0.0105628185, 0.0064862566, -0....
# 40598  [0.014580583, 0.003924127, -0.006412632, 0.009...

# %%
import torch
## Save the Text Embeddings

torch.save(data['Text_Embedding'], 'Text_Embedding.pt')

# %%
from elasticsearch import Elasticsearch

ELASTIC_CLOUD_ID = "SSE:dXMtY2VudHJhbDEuZ2NwLmNsb3VkLmVzLmlvOjQ0MyQwNTJlNmQ5YzgzM2I0NzIwOThmZDk3NmZmODg5MTQ2ZiQxZWI5OWIyMjEzMDc0ZDEyYTM0NGVlODQ4YzkzZDBhNQ=="
ELASTIC_API_KEY = "YWlrYXpJd0JuYnI4ZWpVYU9KM0Y6Q09pQVhhemdSUDZCYWFIangwYnA0QQ=="

# Create the client instance
client = Elasticsearch( 
    cloud_id=ELASTIC_CLOUD_ID,
    api_key=ELASTIC_API_KEY,
    ca_certs= r"C:\Users\vivek\Projects\Sematic Seach Engine\ElasticSearchCertificate\A2525B64D8BFD084D946539261844AC9A3F7DBDC.crt", 
    verify_certs=True
)

## SSE:dXMtY2VudHJhbDEuZ2NwLmNsb3VkLmVzLmlvOjQ0MyQwNTJlNmQ5YzgzM2I0NzIwOThmZDk3NmZmODg5MTQ2ZiQxZWI5OWIyMjEzMDc0ZDEyYTM0NGVlODQ4YzkzZDBhNQ==
## YWlrYXpJd0JuYnI4ZWpVYU9KM0Y6Q09pQVhhemdSUDZCYWFIangwYnA0QQ==

# %%
client.info()
# Out:
# ObjectApiResponse({'name': 'instance-0000000001', 'cluster_name': '052e6d9c833b472098fd976ff889146f', 'cluster_uuid': 'BZxW-B35RZ6cW7wplL9Uuw', 'version': {'number': '8.10.4', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'b4a62ac808e886ff032700c391f45f1408b2538c', 'build_date': '2023-10-11T22:04:35.506990650Z', 'build_snapshot': False, 'lucene_version': '9.7.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
client.indices.delete(index="legal_index", ignore_unavailable=True)
# Out:
# ObjectApiResponse({'acknowledged': True})

# %%
mappings = {
    "properties": {
        "Text_Embedding":{
            "type":"dense_vector",
            "dims":768,
            "index":True,
            "similarity":"cosine"
        }
    }
}

# Create the index
client.indices.create(index='legal_index', mappings=mappings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'legal_index'})

# %%
data = data.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')
data = data.drop(columns=['index'], axis=1)
data.head()
# Out:
#         id                                               name decision_date  \
# 0  8656636  E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL ...    1913-12-10
# 1  8615879                           STATE v. ABRAHAM L. LUFF    1930-04-16
# 2  8616722                             STATE v. FRANK BALLARD    1944-03-22
# 3  8654035  FIRST NATIONAL BANK OF SPARTANBURG, SOUTH CARO...    1924-10-22
# 4  8554475          STATE OF NORTH CAROLINA v. HAROLD EMANUEL    1972-12-20
#
#                                         jurisdiction  \
# 0  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 1  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 2  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 3  {'name_long': 'North Carolina', 'name': 'N.C.'...
# 4  {'name_long': 'North Carolina', 'name': 'N.C.'...
#
#                                          head_matter  \
# 0  E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL ...
# 1  STATE v. ABRAHAM L. LUFF.\n(Filed 16 April, 19...
# 2  STATE v. FRANK BALLARD.\n(Filed 22 March, 1944...
# 3  FIRST NATIONAL BANK OF SPARTANBURG, SOUTH CARO...
# 4  STATE OF NORTH CAROLINA v. HAROLD EMANUEL\nNo....
#
#                                                 text  \
# 0  Clark, C. J.\nTbe plaintiff executed to defend...
# 1  Brogden, J.\nThe defendant contended that the ...
# 2  Pee Cueiam.\nAfter a careful consideration of ...
# 3  Stacy, J.\nThe president and assistant cashier...
# 4  GRAHAM, Judge.\nAfter the case was docketed an...
#
#                                         cleaned_text
# 0  clark c j tbe plaintiff executed defendant bur...
# 1  brogden j defendant contended fund deposited c...
# 2  pee cueiam careful consideration defendant exc...
# 3  stacy j president assistant cashier plaintiff ...
# 4  graham judge case docketed brief filed court d...

# %%
dict = data.to_dict(orient='records')
dict[0]
# Out:
# {'id': 8656636,
#  'name': 'E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL BANK OF NEW BERN',
#  'decision_date': '1913-12-10',
#  'jurisdiction': {'name_long': 'North Carolina',
#   'name': 'N.C.',
#   'whitelisted': True,
#   'id': 5,
#   'url': 'https://api.capapi.org/v1/jurisdictions/nc/',
#   'slug': 'nc'},
#  'head_matter': 'E. C. ARMSTRONG v. J. M. KINSELL and NATIONA
 114 N. C., 465; Heilbetter v. Oil Co., 112 U. S., 294. Bernhardt v. Brown has been repeatedly cited; see Anno. Ed.\nIn this case there was no personal service on the defendant Kinsell nor acceptance of service nor waiver thereof by an appearance. He entered a special appearance and asked to dissolve the injunction and dismiss the proceeding. This is not a proceeding in rem to enforce any lien upon the property or to make partition thereof. Nor has jurisdiction been acquired as in a proceeding quasi in rem, because there has been no attachment issued and levied. An injunction granted before the issuing of a summons is irregular and will be vacated on motion. McArthur v. McEachin, 64 N. C., 72; Hirsh v. Whitehead, 65 N. C., 516. For a stronger reason, it must be vacated when no summons has been served on Kinsell and juri ...
#  'cleaned_text': 'clark c j tbe plaintiff executed defendant burusell two note eacb payable tbe national bank new bern respectively january september tbe balance due purchase merrygoround wbicb bad made casb payment note deposited tbe defendant bank collection arrival tbe machine dissatisfied condition tbe plaintiff brought action alleging false representation breach warranty asking damage tbe extent tbe balance tbe purchase money injunction tbe defendant kinsell negotiating transferring said note tbe bank prevent parting tbe custody thereof tbe order tbe court tbe defendant kinsell entered special appearance asked dismiss tbe action vacate dissolve tbe restraining order upon tbe ground bad personal service tbe summons upon appearance acceptance service asking tbe injunction dissolved tbe action dismissed tbe system procedure prior tbe adoption code injunction special common tbe former tbe injunction tbe relief sought common injunction ancillary proceeding tbe code injunction aresimply ancillary proceeding issue except action pending court wbicb jurisdiction obtained one tbe mode recognized tbe statute fully discussed distinguished bernhardt v brown n c personal service lieu thereof acceptance service waiver appearance proceeding rem wbicb tbe court already jurisdiction re enforce lien partition property control tbe like case publication summons notice may made judgment personal force even cost limited acting upon property proceeding quasi rem case court acquires jurisdiction attaching property nonresident absconding debtor winfree v bagley n c similar eas judgment effect beyond enforcement judgment property seized attachment case publication summons notice may made based upon jurisdiction property attached revisal grocery co v bag co n c proceeding divorce sui generis judgment tliereih merely declares personal status publication summons allowed without acquisition jurisdiction attachment property dfendant nonresident court jurisdiction person plaintiff distinction proceeding method bringing party court fully pointed bernhardt v brown supra p citation authority pennoyer v neff u winfree v bagley n c long v insurance co n c heilbetter v oil co u bernhardt v brown repeatedly cited see anno ed case personal service defendant kinsell acceptance service waiver thereof appearance entered special appearance asked dissolve injunction dismiss proceeding proceeding rem enforce lien upon property make partition thereof jurisdiction acquired proceeding quasi rem attachment issued levied injunction granted issuing summons irregular vacated motion mcarthur v mceachin n c hirsh v whitehead n c stronger reason must vacated summons served kinsell jurisdiction acquired either attachment court control re injunction therefore properly dismissed einsell also bank latter cause action stated absence defendant einsell see advantage plaintiff injunction bank even einsell attachment procured moreover injunction nonresident improvident effect usually least except personam warlick v reynolds n c jurisdiction acquired einsell service attachment upon note revisal publication notice based jurisdiction thus acquired best v mortgage co n c grocery co v bag co n c winfree v bagley n c held well considered opinion shepherd j chose action property embraced term code provides service publication defendant resident state property therein case repeatedly cited since see anno ed case publication notice acquire ment jurisdiction attachment note plaintiff ask amend proceeding making attachment publication judgment dismissing action affirmed'}

# %%
with open("data_reduce_new.json", "w") as outfile: 
    json.dump(dict, outfile)

docs = json.load(open("data_reduce_new.json"))

# %%
docs = json.load(open("data_reduce_new.json"))

# %%
operations = []
for doc in docs:
    temp = doc.copy()
    temp["index"] = {"_index": "legal_index"}
    # Transforming the title into an embedding using the model
    temp["Text_Embedding"] = model.encode(temp["cleaned_text"]).tolist()
    operations.append(temp)

operations[0]
# Out:
# {'id': 8656636,
#  'name': 'E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL BANK OF NEW BERN',
#  'decision_date': '1913-12-10',
#  'jurisdiction': {'name_long': 'North Carolina',
#   'name': 'N.C.',
#   'whitelisted': True,
#   'id': 5,
#   'url': 'https://api.capapi.org/v1/jurisdictions/nc/',
#   'slug': 'nc'},
#  'head_matter': 'E. C. ARMSTRONG v. J. M. KINSELL and NATIONAL BANK OF NEW BERN.\n(Filed 10 December, 1913.)\n1. Injunctions — Distinctions Abolished — Code Practice — Interpretation of Statutes.\nUnder our Code practice the difference between special and common injunctions has been abolished, and they are ancillary to the relief sought in the actioh, and dependent upon service of process upon the defendant therein in accordance with the modes recognized by statute.\n2. Injunctions — Bills and Notes — Banks and Banking — Nonresident Defendant — Process—Attachment.\nWhere the maker of a note brings his action against a nonresident payee to impeach his note upon the ground of fraud or false representations in its procurement, and seeks an injunction restraining the payee from further negotiating it, and a resident bank, where it had been deposited, from parting with its possession, it is necessary to show personal service of the summons on the nonresident defendant or his duly authorized agent, or some act of his amounting to a waiver thereof; and the issuance of the restraining order on the bank, depending upon proper service of process on the payee, will likewise be dismissed where a special appearance has been entered for that purpose, and there has been no service or waiver of process by the nonresident defendant. The remedy is by attachment of the note in the hands of the bank, under the provisions of Revisal, sec. 777, and publication of notice to the nonresident defendant based thereon. Bernhardt v. Brown, 118 N. C., 701, cited and applied.\nAppeal by plaintiff from Whedbee, J., at October Term, 1913, of CRAVEN.\nErnest M. Green for plaintiff.\nCharles R. Thomas for defendants.',
#  'text': "Clark, C. J.\nTbe plaintiff executed to defendant Burusell two notes for $400 eacb, payable at tbe National Bank of New Bern, respectively,- on 3 January, 1914, and 3 September, 1914, for tbe balance due on purchase of a “merry-go-round” on wbicb be bad made a casb payment. These notes were deposited with tbe defendant bank for collection. On arrival of tbe machine, being dissatisfied with its condition, tbe plaintiff brought this action, alleging false representation and breach of warranty and asking damages to tbe extent of tbe balance, of tbe purchase money and an injunction against tbe defendant Kinsell from negotiating or transferring said notes and against tbe bank to prevent its parting with tbe custody thereof until tbe further orders of tbe court.\nTbe defendant Kinsell entered a special appearance and asked to dismiss tbe action and to vacate and dissolve tbe 'restraining order, upon tbe ground that there bad been no personal service of tbe summons upon him and no appearance, or acceptance of service, and asking that tbe injunction be dissolved and that tbe action be dismissed.\n. Under tbe system of procedure prior to tbe adoption of The Code, injunctions were special or common. Tbe former was where tbe injunction itself was tbe relief sought, while a common injunction was an ancillary proceeding; but under Tbe Code all injunctions are'simply ancillary proceedings and cannot issue except when there is an action pending in court, in wbicb jurisdiction has been obtained in one of tbe modes recognized by tbe statute. These are fully discussed and distinguished in Bernhardt v. Brown, 118 N. C., 701. They are:\n(1) Personal service, or, in lieu thereof, acceptance of service or a waiver by appearance.\n(2) Proceedings in rem, in wbicb tbe court already has jurisdiction of the, res as to enforce some lien or a partition of property in its control, and tbe like. In these cases publication of the' summons or notice may be made, but the judgment has no
ied injunction granted issuing summons irregular vacated motion mcarthur v mceachin n c hirsh v whitehead n c stronger reason must vacated summons served kinsell jurisdiction acquired either attachment court control re injunction therefore properly dismissed einsell also bank latter cause action stated absence defendant einsell see advantage plaintiff injunction bank even einsell attachment procured moreover injunction nonresident improvident effect usually least except personam warlick v reynolds n c jurisdiction acquired einsell service attachment upon note revisal publication notice based jurisdiction thus acquired best v mortgage co n c grocery co v bag co n c winfree v bagley n c held well considered opinion shepherd j chose action property embraced term code provides service publication defendant resident state property therein case repeatedly cited since see anno ed case publication notice acquire ment jurisdiction attachment note plaintiff ask amend proceeding making attachment publication judgment dismissing action affirmed',
#  'index': {'_index': 'legal_index'},
#  'Text_Embedding': [0.014324145391583443,
#   0.013309592381119728,
#   -0.013124680146574974,
#   0.0038903052918612957,
#   0.004694465547800064,
#   -0.05366747826337814,
#   0.022522959858179092,
#   0.03786513954401016,
#   0.006451187655329704,
#   -0.006624097004532814,
#   0.004960698075592518,
#   0.014059522189199924,
#   0.01911511830985546,
#   0.026409922167658806,
#   -0.007350873667746782,
#   -0.03796905279159546,
#   0.03880907595157623,
#   0.02683325670659542,
#   0.0014167552581056952,
#   0.00871738325804472,
#   0.011795862577855587,
#   -0.024166865274310112,
#   0.09075772762298584,
#   0.031659338623285294,
#   0.038129739463329315,
#   0.026444772258400917,
#   0.03707830607891083,
#   0.003910501021891832,
#   0.024290893226861954,
#   0.007024054415524006,
#   0.01677289605140686,
#   0.03579866513609886,
#   -0.003622674150392413,
#   0.011389756575226784,
#   -0.039289943873882294,
#   0.017338626086711884,
#   0.04925385117530823,
#   0.012643947266042233,
#   0.02493392303586006,
#   -0.058010853826999664,
#   0.019028661772608757,
#   0.07669398188591003,
#   0.002604676177725196,
#   0.0036810259334743023,
#   0.002702579600736499,
#   -0.030450617894530296,
#   -0.03804738447070122,
#   -0.03871870040893555,
#   -0.018069179728627205,
#   0.006223784759640694,
#   0.018320707604289055,
#   -0.00501845171675086,
#   0.017185628414154053,
#   0.01318198349326849,
#   -0.06274055689573288,
#   0.05058327317237854,
#   -0.017657309770584106,
#   -0.02711881697177887,
#   -0.015336793847382069,
#   0.017387069761753082,
#   0.019164390861988068,
#   0.02259436622262001,
#   -0.054707154631614685,
#   0.043840792030096054,
#   0.06604044139385223,
#   -0.028611736372113228,
#   -0.049224190413951874,
#   -0.034152302891016006,
#   -0.013333857990801334,
#   0.034953802824020386,
#   -0.020860832184553146,
#   -0.010496167466044426,
#   0.0050678797997534275,
#   -0.0777861624956131,
#   0.06762821227312088,
#   -0.049540113657712936,
#   -0.01593097671866417,
#   -0.029486466199159622,
#   -0.03287887200713158,
#   0.06675338000059128,
#   -0.01779129169881344,
#   0.043438151478767395,
#   0.054540473967790604,
#   0.051557205617427826,
#   -0.025403723120689392,
#   -0.03333180770277977,
#   0.00779479555785656,
#   -0.014604727737605572,
#   0.026901645585894585,
#   0.031322941184043884,
#   -0.02567722462117672,
#   -0.03656380996108055,
#   0.0018037522677332163,
#   -0.008034873753786087,
#   -0.031994592398405075,
#   0.006622484885156155,
#   -0.05031654238700867,
#   0.10198893398046494,
#   -0.017469041049480438,
#   0.04688866809010506,
#   0.062054187059402466,
#   0.021895118057727814,
#   -0.020109442993998528,
#   0.0843777060508728,
#   0.04413376748561859,
#   0.04789331555366516,
#   0.05524355173110962,
#   -0.011942069046199322,
#   0.050118476152420044,
#   0.044156160205602646,
#   -0.0600036084651947,
#   0.0288609080016613,
#   -0.06169930100440979,
#   0.005936439149081707,
#   0.04661034047603607,
#   -0.03801656514406204,
#   -0.012975772842764854,
#   0.020052479580044746,
#   0.022933246567845345,
#   -0.01584738865494728,
#   0.0014043572591617703,
#   -0.04651293903589249,
#   0.035428810864686966,
#   0.06394550949335098,
#   -0.04784402996301651,
#   -0.01345927082002163,
#   0.017297333106398582,
#   -0.024636676535010338,
#   0.021995840594172478,
#   0.02277967520058155,
#   -0.026934010908007622,
#   0.021110018715262413,
#   -0.003107554977759719,
#   0.01555095985531807,
#   -0.005409351550042629,
#   0.003097895998507738,
#   0.03542182594537735,
#   0.045650094747543335,
#   -0.06464862823486328,
#   0.037465665489435196]}

# %%
len(operations)
# Out:
# 19516

# %%
temp = operations.copy()
temp = temp[:100]
len(temp)
# Out:
# 100

# %%
client.bulk(index="legal_index", operations=temp, refresh=True)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 client.bulk(index="legal_index", operations=temp, refresh=True)
#
# File c:\Users\vivek\anaconda3\envs\SSE-venv\lib\site-packages\elasticsearch\_sync\client\utils.py:402, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     399         except KeyError:
#     400             pass
# --> 402 return api(*args, **kwargs)
#
# File c:\Users\vivek\anaconda3\envs\SSE-venv\lib\site-packages\elasticsearch\_sync\client\__init__.py:702, in Elasticsearch.bulk(self, operations, index, error_trace, filter_path, human, pipeline, pretty, refresh, require_alias, routing, source, source_excludes, source_includes, timeout, wait_for_active_shards)
#     697 __body = operations
#     698 __headers = {
#     699     "accept": "application/json",
#     700     "content-type": "application/x-ndjson",
#     701 }
# --> 702 return self.perform_request(  # type: ignore[return-value]
#     703     "PUT", __path, params=__query, headers=__headers, body=__body
#     704 )
#
# File c:\Users\vivek\anaconda3\envs\SSE-venv\lib\site-packages\elasticsearch\_sync\client\_base.py:320, in BaseClient.perform_request(self, method, path, params, headers, body)
#     317         except (ValueError, KeyError, TypeError):
#     318             pass
# --> 320     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     321         message=message, meta=meta, body=resp_body
#     322     )
#     324 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     325 if not self._verified_elasticsearch:
#     326     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'illegal_argument_exception', 'Malformed action/metadata line [1], expected field [create], [delete], [index] or [update] but found [id]')

# %%
def pretty_response(response):
    if len(response['hits']['hits']) == 0:
        print('Your search returned no results.')
    else:
        for hit in response['hits']['hits']:
            id = hit['_id']
            id_ = hit['_source']['id']
            score = hit['_score']
            name = hit['_source']['name']
            decision_date = hit['_source']['decision_date']
            head_matter = hit["_source"]["head_matter"]

            pretty_output = (f"\nID: {id}\nindex: {id_}\Name: {name}\ndecision_date: {decision_date}\ndhead_matter: {head_matter}\nScore: {score}")
            print(pretty_output)

# %%
response = client.search(
    index="book_index",
    knn={
      "field": "title_vector",
      "query_vector": model.encode("NATIONAL BANK OF NEW BERN"),
      "k": 10,
      "num_candidates": 100
    }
)

pretty_response(response)
